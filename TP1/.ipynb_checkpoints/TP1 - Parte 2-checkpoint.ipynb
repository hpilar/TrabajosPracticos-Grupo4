# %% [markdown]
# # Tutorial de Big Data
# ## Bienvenidos a la clase 3
#
# ### Temario:
#
# - Introducción a tweepy, textblob, nltk
# - Ejercicio práctico: Analisis de sentimiento de tweets de Joe Biden pre y post elecciones
# - Introducción al TP1 parte 2
# - GitHub para entregar los TPs

# %% [markdown]
# ### Analisis de sentimiento de tweets de Joe Biden pre y post elecciones

# %%
import sys
# !{sys.executable} -m pip install textblob

# %%
import sys
# !{sys.executable} -m pip install tweepy

# %%
import sys
# !{sys.executable} -m pip install timeline

# %%
import sys
# !{sys.executable} -m pip install matplotlib

# %%
#importamos los paquetes a utilizar
import os
import re
import string
from datetime import timezone as tz
from datetime import datetime 
from timeline import timeline

import pandas as pd
import tweepy
from textblob import TextBlob
import nltk
nltk.download('stopwords')
nltk.download('punkt')
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

#Si alguien quiere trabajar con alguna cuenta en español podrían instalar 
#sentiment_analysis_spanish y utilizarlo en reemplado de TextBlob:
#!{sys.executable} -m pip install sentiment_analysis_spanish
#from sentiment_analysis_spanish import sentiment_analysis
# y pueden crearse una lista de stopwords con las de este link:
# https://github.com/xiamx/node-nltk-stopwords/blob/master/data/stopwords/spanish
# También usaremos string.punctuation. Si trabajan en español podrian agregarle  
# ¿ y ¡ . En ingles incluye lo siguiente: !"#$%&'()*+, -./:;<=>?@[\]^_`{|}~
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Matias\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Matias\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# Para generar las claves vayan a:
# https://developer.twitter.com/en/portal/dashboard
#
# - Luego a Projects & Apps
# - Luego Overview
# - Luego + Create App
#
# Crear con Sublime (u otro editor de texto) un archivo llamado `twitter_keys.txt` dentro de la carpeta `Tutorial3` y guardar las 4 claves, una por línea, en el siguiente orden:
# - API key
# - API key secret
# - Access token
# - Access token secret

# %%
#Creamos variables que contienen nuestas claves de autenticación con la API
with open("twitter_keys.txt") as tw_k: 
    consumer_key = tw_k.readline().strip()
    consumer_secret = tw_k.readline().strip()
    access_key = tw_k.readline().strip()
    access_secret = tw_k.readline().strip()

# %%
#Le pasamos nuestras credenciales de twitter a tweepy
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_key, access_secret)
api = tweepy.API(auth)

# %% [markdown]
# En este link pueden explorar detalles del metodo user_timeline: https://docs.tweepy.org/en/stable/api.html?highlight=user_timeline#tweepy.API.user_timeline

# %%
api.user_timeline(screen_name="JoeBiden",tweet_mode="extended")
# Out:
# [Status(_api=<tweepy.api.API object at 0x0000018A39C1B2B0>, _json={'created_at': 'Fri Aug 26 23:07:00 +0000 2022', 'id': 1563302019032846336, 'id_str': '1563302019032846336', 'full_text': 'Senator Rick Scott wrote the only election-year plan the GOP has this year—in it, he wants to require Congress to vote on the future of Social Security every 5 years.\n\nDo you want to put your Social Security into the hands of Ted Cruz or Marjorie Taylor Greene?', 'truncated': False, 'display_text_range': [0, 261], 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []}, 'source': '<a href="https://sproutsocial.com" rel="nofollow">Sprout Social</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 939091, 'id_str': '939091', 'name': 'Joe Biden', 'screen_name': 'JoeBiden', 'location': 'Washington, DC', 'description': 'Husband to @DrBiden, proud father and grandfather. Ready to build back better for all Americans. Official account is @POTUS.', 'url': 'https://t.co/UClrPuJpyZ', 'entities': {'url': {'urls': [{'url': 'https://t.co/UClrPuJpyZ', 'expanded_url': 'http://joebiden.com', 'display_url': 'joebiden.com', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 35261195, 'friends_count': 48, 'listed_count': 39764, 'created_at': 'Sun Mar 11 17:51:24 +0000 2007', 'favourites_count': 20, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': True, 'statuses_count': 8429, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '565959', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1308769664240160770/AfgzWVE7_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1308769664240160770/AfgzWVE7_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/939091/1626295479', 'profile_link_color': '233F94', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': 'EBEBFF', 'profile_text_color': '323232', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 8534, 'favorite_count': 31051, 'favorited': False, 'retweeted': False, 'lang': 'en'}, created_at=datetime.datetime(2022, 8, 26, 23, 7, tzinfo=datetime.timezone.utc), id=1563302019032846336, id_str='1563302019032846336', full_text='Senator Rick Scott wrote the only election-year plan the GOP has this year—in it, he wants to require Congress to vote on the future of Social Security every 5 years.\n\nDo you want to put your Social Security into the hands of Ted Cruz or Marjorie Taylor Greene?', truncated=False, display_text_range=[0, 261], entities={'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []}, source='Sprout Social', source_url='https://sproutsocial.com', in_reply_to_status_id=None, in_reply_to_status_id_str=None, in_reply_to_user_id=None, in_reply_to_user_id_str=None, in_reply_to_screen_name=None, author=User(_api=<tweepy.api.API object at 0x0000018A39C1B2B0>, _json={'id': 939091, 'id_str': '939091', 'name': 'Joe Biden', 'screen_name': 'JoeBiden', 'location': 'Washington, DC', 'description': 'Husband to @DrBiden, proud father and grandfather. Ready to build back better for all Americans. Official account is @POTUS.', 'url': 'https://t.co/UClrPuJpyZ', 'entities': {'url': {'urls': [{'url': 'https://t.co/UClrPuJpyZ', 'expanded_url ...
#  Status(_api=<tweepy.api.API object at 0x0000018A39C1B2B0>, _json={'created_at': 'Fri Aug 26 21:55:01 +0000 2022', 'id': 1563283902898114562, 'id_str': '1563283902898114562', 'full_text': 'Under my student debt relief plan, almost 90% of the benefit will go to folks making less than $75,000 a year.', 'truncated': False, 'display_text_range': [0, 110], 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []}, 'source': '<a href="https://sproutsocial.com" rel="nofollow">Sprout Social</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 939091, 'id_str': '939091', 'name': 'Joe Biden', 'screen_name': 'JoeBiden', 'location': 'Washington, DC', 'description': 'Husband to @DrBiden, proud father and grandfather. Ready to build back better for all Americans. Official account is @POTUS.', 'url': 'https://t.co/UClrPuJpyZ', 'entities': {'url': {'urls': [{'url': 'https://t.co/UClrPuJpyZ', 'expanded_url': 'http://joebiden.com', 'display_url': 'joebiden.com', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 35261195, 'friends_count': 48, 'listed_count': 39764, 'created_at': 'Sun Mar 11 17:51:24 +0000 2007', 'favourites_count': 20, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': True, 'statuses_count': 8429, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '565959', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1308769664240160770/AfgzWVE7_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1308769664240160770/AfgzWVE7_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/939091/1626295479', 'profile_link_color': '233F94', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': 'EBEBFF', 'profile_text_color': '323232', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 2346, 'favorite_count': 17539, 'favorited': False, 'retweeted': False, 'lang': 'en'}, created_at=datetime.datetime(2022, 8, 26, 21, 55, 1, tzinfo=datetime.timezone.utc), id=1563283902898114562, id_str='1563283902898114562', full_text='Under my student debt relief plan, almost 90% of the benefit will go to folks making less than $75,000 a year.', truncated=False, display_text_range=[0, 110], entities={'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []}, source='Sprout Social', source_url='https://sproutsocial.com', in_reply_to_status_id=None, in_reply_to_status_id_str=None, in_reply_to_user_id=None, in_reply_to_user_id_str=None, in_reply_to_screen_name=None, author=User(_api=<tweepy.api.API object at 0x0000018A39C1B2B0>, _json={'id': 939091, 'id_str': '939091', 'name': 'Joe Biden', 'screen_name': 'JoeBiden', 'location': 'Washington, DC', 'description': 'Husband to @DrBiden, proud father and grandfather. Ready to build back better for all Americans. Official account is @POTUS.', 'url': 'https://t.co/UClrPuJpyZ', 'entities': {'url': {'urls': [{'url': 'https://t.co/UClrPuJpyZ', 'expanded_url': 'http://joebiden.com', 'display_url': 'joebiden.com', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 35261195, 'friends_count': 48, 'listed_count': 39764, 'created_at': 'Sun Mar 11 17:51:24 +0000 2007', 'favourites_count': 20, 'utc_offset': None, 'time_z ...
#  Status(_api=<tweepy.api.API object at 0x0000018A39C1B2B0>, _json={'created_at': 'Fri Aug 26 18:52:01 +0000 2022', 'id': 1563237850115878917, 'id_str': '1563237850115878917', 'full_text': '10 million jobs—more than ever created before at this point of a presidency. \n3.5% unemployment rate—a near record low in the history of this country. \nMore than 220 million Americans were vaccinated. \nRecord small business creation. \n\nThat’s our economic record.', 'truncated': False, 'display_text_range': [0, 263], 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []}, 'source': '<a href="https://sproutsocial.com" rel="nofollow">Sprout Social</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 939091, 'id_str': '939091', 'name': 'Joe Biden', 'screen_name': 'JoeBiden', 'location': 'Washington, DC', 'description': 'Husband to @DrBiden, proud father and grandfather. Ready to build back better for all Americans. Official account is @POTUS.', 'url': 'https://t.co/UClrPuJpyZ', 'entities': {'url': {'urls': [{'url': 'https://t.co/UClrPuJpyZ', 'expanded_url': 'http://joebiden.com', 'display_url': 'joebiden.com', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 35261195, 'friends_count': 48, 'listed_count': 39764, 'created_at': 'Sun Mar 11 17:51:24 +0000 2007', 'favourites_count': 20, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': True, 'statuses_count': 8429, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '565959', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1308769664240160770/AfgzWVE7_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1308769664240160770/AfgzWVE7_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/939091/1626295479', 'profile_link_color': '233F94', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': 'EBEBFF', 'profile_text_color': '323232', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 1988, 'favorite_count': 9864, 'favorited': False, 'retweeted': False, 'lang': 'en'}, created_at=datetime.datetime(2022, 8, 26, 18, 52, 1, tzinfo=datetime.timezone.utc), id=1563237850115878917, id_str='1563237850115878917', full_text='10 million jobs—more than ever created before at this point of a presidency. \n3.5% unemployment rate—a near record low in the history of this country. \nMore than 220 million Americans were vaccinated. \nRecord small business creation. \n\nThat’s our economic record.', truncated=False, display_text_range=[0, 263], entities={'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []}, source='Sprout Social', source_url='https://sproutsocial.com', in_reply_to_status_id=None, in_reply_to_status_id_str=None, in_reply_to_user_id=None, in_reply_to_user_id_str=None, in_reply_to_screen_name=None, author=User(_api=<tweepy.api.API object at 0x0000018A39C1B2B0>, _json={'id': 939091, 'id_str': '939091', 'name': 'Joe Biden', 'screen_name': 'JoeBiden', 'location': 'Washington, DC', 'description': 'Husband to @DrBiden, proud father and grandfather. Ready to build back better for all Americans. Official account is @POTUS.', 'url': 'https://t.co/UClrPuJpyZ', 'entities': {'url': {'urls': [{'url': 'https://t.co/UClrPuJpyZ',  ...
#  Status(_api=<tweepy.api.API object at 0x0000018A39C1B2B0>, _json={'created_at': 'Fri Aug 26 17:14:03 +0000 2022', 'id': 1563213196348993542, 'id_str': '1563213196348993542', 'full_text': 'Every Republican in Congress voted against lower prescription drug prices.\n \nAgainst lower health care costs.\nAgainst a fairer tax system.\nAgainst tackling the climate crisis.\nAgainst lowering your energy costs.\nAgainst creating good-paying jobs.\n\nThey chose the already-powerful.', 'truncated': False, 'display_text_range': [0, 280], 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []}, 'source': '<a href="https://sproutsocial.com" rel="nofollow">Sprout Social</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 939091, 'id_str': '939091', 'name': 'Joe Biden', 'screen_name': 'JoeBiden', 'location': 'Washington, DC', 'description': 'Husband to @DrBiden, proud father and grandfather. Ready to build back better for all Americans. Official account is @POTUS.', 'url': 'https://t.co/UClrPuJpyZ', 'entities': {'url': {'urls': [{'url': 'https://t.co/UClrPuJpyZ', 'expanded_url': 'http://joebiden.com', 'display_url': 'joebiden.com', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 35261195, 'friends_count': 48, 'listed_count': 39764, 'created_at': 'Sun Mar 11 17:51:24 +0000 2007', 'favourites_count': 20, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': True, 'statuses_count': 8429, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '565959', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1308769664240160770/AfgzWVE7_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1308769664240160770/AfgzWVE7_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/939091/1626295479', 'profile_link_color': '233F94', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': 'EBEBFF', 'profile_text_color': '323232', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 3072, 'favorite_count': 12850, 'favorited': False, 'retweeted': False, 'lang': 'en'}, created_at=datetime.datetime(2022, 8, 26, 17, 14, 3, tzinfo=datetime.timezone.utc), id=1563213196348993542, id_str='1563213196348993542', full_text='Every Republican in Congress voted against lower prescription drug prices.\n \nAgainst lower health care costs.\nAgainst a fairer tax system.\nAgainst tackling the climate crisis.\nAgainst lowering your energy costs.\nAgainst creating good-paying jobs.\n\nThey chose the already-powerful.', truncated=False, display_text_range=[0, 280], entities={'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []}, source='Sprout Social', source_url='https://sproutsocial.com', in_reply_to_status_id=None, in_reply_to_status_id_str=None, in_reply_to_user_id=None, in_reply_to_user_id_str=None, in_reply_to_screen_name=None, author=User(_api=<tweepy.api.API object at 0x0000018A39C1B2B0>, _json={'id': 939091, 'id_str': '939091', 'name': 'Joe Biden', 'screen_name': 'JoeBiden', 'location': 'Washington, DC', 'description': 'Husband to @DrBiden, proud father and grandfather. Ready to build back better for all Americans. Official account is @POTUS.', 'url': 'https://t.co/UClrPuJpyZ', 'entities': {'url': {'ur ...
#  Status(_api=<tweepy.api.API object at 0x0000018A39C1B2B0>, _json={'created_at': 'Fri Aug 26 00:08:06 +0000 2022', 'id': 1562955005228765186, 'id_str': '1562955005228765186', 'full_text': 'Wall Street didn’t build this country. You did. The working people—the middle class—built this nation. And unions built the middle class.\n\nWe won’t let anyone or anything tear America apart.', 'truncated': False, 'display_text_range': [0, 190], 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 939091, 'id_str': '939091', 'name': 'Joe Biden', 'screen_name': 'JoeBiden', 'location': 'Washington, DC', 'description': 'Husband to @DrBiden, proud father and grandfather. Ready to build back better for all Americans. Official account is @POTUS.', 'url': 'https://t.co/UClrPuJpyZ', 'entities': {'url': {'urls': [{'url': 'https://t.co/UClrPuJpyZ', 'expanded_url': 'http://joebiden.com', 'display_url': 'joebiden.com', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 35261195, 'friends_count': 48, 'listed_count': 39764, 'created_at': 'Sun Mar 11 17:51:24 +0000 2007', 'favourites_count': 20, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': True, 'statuses_count': 8429, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '565959', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1308769664240160770/AfgzWVE7_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1308769664240160770/AfgzWVE7_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/939091/1626295479', 'profile_link_color': '233F94', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': 'EBEBFF', 'profile_text_color': '323232', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 3936, 'favorite_count': 23208, 'favorited': False, 'retweeted': False, 'lang': 'en'}, created_at=datetime.datetime(2022, 8, 26, 0, 8, 6, tzinfo=datetime.timezone.utc), id=1562955005228765186, id_str='1562955005228765186', full_text='Wall Street didn’t build this country. You did. The working people—the middle class—built this nation. And unions built the middle class.\n\nWe won’t let anyone or anything tear America apart.', truncated=False, display_text_range=[0, 190], entities={'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []}, source='Twitter Web App', source_url='https://mobile.twitter.com', in_reply_to_status_id=None, in_reply_to_status_id_str=None, in_reply_to_user_id=None, in_reply_to_user_id_str=None, in_reply_to_screen_name=None, author=User(_api=<tweepy.api.API object at 0x0000018A39C1B2B0>, _json={'id': 939091, 'id_str': '939091', 'name': 'Joe Biden', 'screen_name': 'JoeBiden', 'location': 'Washington, DC', 'description': 'Husband to @DrBiden, proud father and grandfather. Ready to build back better for all Americans. Official account is @POTUS.', 'url': 'https://t.co/UClrPuJpyZ', 'entities': {'url': {'urls': [{'url': 'https://t.co/UClrPuJpyZ', 'expanded_url': 'http://joebiden.com', 'display_url': 'joebiden.com', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'f ...
#  Status(_api=<tweepy.api.API object at 0x0000018A39C1B2B0>, _json={'created_at': 'Fri Aug 26 00:01:41 +0000 2022', 'id': 1562953391441334275, 'id_str': '1562953391441334275', 'full_text': 'Every election is a choice. My dad used to say: “Don’t compare me to the Almighty. Compare me to the alternative.”\n\nWell, the alternative to the Democrats is the MAGA Republicans.', 'truncated': False, 'display_text_range': [0, 179], 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 939091, 'id_str': '939091', 'name': 'Joe Biden', 'screen_name': 'JoeBiden', 'location': 'Washington, DC', 'description': 'Husband to @DrBiden, proud father and grandfather. Ready to build back better for all Americans. Official account is @POTUS.', 'url': 'https://t.co/UClrPuJpyZ', 'entities': {'url': {'urls': [{'url': 'https://t.co/UClrPuJpyZ', 'expanded_url': 'http://joebiden.com', 'display_url': 'joebiden.com', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 35261195, 'friends_count': 48, 'listed_count': 39764, 'created_at': 'Sun Mar 11 17:51:24 +0000 2007', 'favourites_count': 20, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': True, 'statuses_count': 8429, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '565959', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1308769664240160770/AfgzWVE7_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1308769664240160770/AfgzWVE7_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/939091/1626295479', 'profile_link_color': '233F94', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': 'EBEBFF', 'profile_text_color': '323232', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 13570, 'favorite_count': 77822, 'favorited': False, 'retweeted': False, 'lang': 'en'}, created_at=datetime.datetime(2022, 8, 26, 0, 1, 41, tzinfo=datetime.timezone.utc), id=1562953391441334275, id_str='1562953391441334275', full_text='Every election is a choice. My dad used to say: “Don’t compare me to the Almighty. Compare me to the alternative.”\n\nWell, the alternative to the Democrats is the MAGA Republicans.', truncated=False, display_text_range=[0, 179], entities={'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []}, source='Twitter Web App', source_url='https://mobile.twitter.com', in_reply_to_status_id=None, in_reply_to_status_id_str=None, in_reply_to_user_id=None, in_reply_to_user_id_str=None, in_reply_to_screen_name=None, author=User(_api=<tweepy.api.API object at 0x0000018A39C1B2B0>, _json={'id': 939091, 'id_str': '939091', 'name': 'Joe Biden', 'screen_name': 'JoeBiden', 'location': 'Washington, DC', 'description': 'Husband to @DrBiden, proud father and grandfather. Ready to build back better for all Americans. Official account is @POTUS.', 'url': 'https://t.co/UClrPuJpyZ', 'entities': {'url': {'urls': [{'url': 'https://t.co/UClrPuJpyZ', 'expanded_url': 'http://joebiden.com', 'display_url': 'joebiden.com', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 352 ...
#  Status(_api=<tweepy.api.API object at 0x0000018A39C1B2B0>, _json={'created_at': 'Fri Aug 26 00:00:08 +0000 2022', 'id': 1562953001710788611, 'id_str': '1562953001710788611', 'full_text': 'Every single Republican voted against:\n❌ Lowering prescription drug prices\n❌ Lower health care costs\n❌ Tackling the climate crisis\n❌ Lower energy costs\n❌ Creating good-paying jobs\n❌ A fairer tax system', 'truncated': False, 'display_text_range': [0, 201], 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 939091, 'id_str': '939091', 'name': 'Joe Biden', 'screen_name': 'JoeBiden', 'location': 'Washington, DC', 'description': 'Husband to @DrBiden, proud father and grandfather. Ready to build back better for all Americans. Official account is @POTUS.', 'url': 'https://t.co/UClrPuJpyZ', 'entities': {'url': {'urls': [{'url': 'https://t.co/UClrPuJpyZ', 'expanded_url': 'http://joebiden.com', 'display_url': 'joebiden.com', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 35261195, 'friends_count': 48, 'listed_count': 39764, 'created_at': 'Sun Mar 11 17:51:24 +0000 2007', 'favourites_count': 20, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': True, 'statuses_count': 8429, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '565959', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1308769664240160770/AfgzWVE7_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1308769664240160770/AfgzWVE7_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/939091/1626295479', 'profile_link_color': '233F94', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': 'EBEBFF', 'profile_text_color': '323232', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 7084, 'favorite_count': 28291, 'favorited': False, 'retweeted': False, 'lang': 'en'}, created_at=datetime.datetime(2022, 8, 26, 0, 0, 8, tzinfo=datetime.timezone.utc), id=1562953001710788611, id_str='1562953001710788611', full_text='Every single Republican voted against:\n❌ Lowering prescription drug prices\n❌ Lower health care costs\n❌ Tackling the climate crisis\n❌ Lower energy costs\n❌ Creating good-paying jobs\n❌ A fairer tax system', truncated=False, display_text_range=[0, 201], entities={'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []}, source='Twitter Web App', source_url='https://mobile.twitter.com', in_reply_to_status_id=None, in_reply_to_status_id_str=None, in_reply_to_user_id=None, in_reply_to_user_id_str=None, in_reply_to_screen_name=None, author=User(_api=<tweepy.api.API object at 0x0000018A39C1B2B0>, _json={'id': 939091, 'id_str': '939091', 'name': 'Joe Biden', 'screen_name': 'JoeBiden', 'location': 'Washington, DC', 'description': 'Husband to @DrBiden, proud father and grandfather. Ready to build back better for all Americans. Official account is @POTUS.', 'url': 'https://t.co/UClrPuJpyZ', 'entities': {'url': {'urls': [{'url': 'https://t.co/UClrPuJpyZ', 'expanded_url': 'http://joebiden.com', 'display_url': 'joebiden.com', 'indices': [0, 23]}]}, 'description': {'urls' ...
#  Status(_api=<tweepy.api.API object at 0x0000018A39C1B2B0>, _json={'created_at': 'Thu Aug 25 23:55:34 +0000 2022', 'id': 1562951850357583872, 'id_str': '1562951850357583872', 'full_text': 'We had to take on the big drug companies to pass the Inflation Reduction Act.\n\nFor decades, Big Pharma fought to block giving Medicare the power to negotiate for lower prices.\n\nAnd, for decades, Big Pharma won.\n\nNot this year. The American people won. And big pharma lost.', 'truncated': False, 'display_text_range': [0, 272], 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 939091, 'id_str': '939091', 'name': 'Joe Biden', 'screen_name': 'JoeBiden', 'location': 'Washington, DC', 'description': 'Husband to @DrBiden, proud father and grandfather. Ready to build back better for all Americans. Official account is @POTUS.', 'url': 'https://t.co/UClrPuJpyZ', 'entities': {'url': {'urls': [{'url': 'https://t.co/UClrPuJpyZ', 'expanded_url': 'http://joebiden.com', 'display_url': 'joebiden.com', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 35261195, 'friends_count': 48, 'listed_count': 39764, 'created_at': 'Sun Mar 11 17:51:24 +0000 2007', 'favourites_count': 20, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': True, 'statuses_count': 8429, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '565959', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1308769664240160770/AfgzWVE7_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1308769664240160770/AfgzWVE7_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/939091/1626295479', 'profile_link_color': '233F94', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': 'EBEBFF', 'profile_text_color': '323232', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 1596, 'favorite_count': 8813, 'favorited': False, 'retweeted': False, 'lang': 'en'}, created_at=datetime.datetime(2022, 8, 25, 23, 55, 34, tzinfo=datetime.timezone.utc), id=1562951850357583872, id_str='1562951850357583872', full_text='We had to take on the big drug companies to pass the Inflation Reduction Act.\n\nFor decades, Big Pharma fought to block giving Medicare the power to negotiate for lower prices.\n\nAnd, for decades, Big Pharma won.\n\nNot this year. The American people won. And big pharma lost.', truncated=False, display_text_range=[0, 272], entities={'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []}, source='Twitter Web App', source_url='https://mobile.twitter.com', in_reply_to_status_id=None, in_reply_to_status_id_str=None, in_reply_to_user_id=None, in_reply_to_user_id_str=None, in_reply_to_screen_name=None, author=User(_api=<tweepy.api.API object at 0x0000018A39C1B2B0>, _json={'id': 939091, 'id_str': '939091', 'name': 'Joe Biden', 'screen_name': 'JoeBiden', 'location': 'Washington, DC', 'description': 'Husband to @DrBiden, proud father and grandfather. Ready to build back better for all Americans. Official account is @POTUS.', 'url': 'https://t.co/UClrPuJpyZ', 'entities': {'url': {'urls': [{'url' ...
#  Status(_api=<tweepy.api.API object at 0x0000018A39C1B2B0>, _json={'created_at': 'Thu Aug 25 23:50:30 +0000 2022', 'id': 1562950578296147968, 'id_str': '1562950578296147968', 'full_text': 'In 2020, 81 million Americans voted to save our democracy.\n\nThat’s why Donald Trump isn’t just a former president. He’s a defeated former president.\n\nNow, you need to vote to save democracy again.', 'truncated': False, 'display_text_range': [0, 196], 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 939091, 'id_str': '939091', 'name': 'Joe Biden', 'screen_name': 'JoeBiden', 'location': 'Washington, DC', 'description': 'Husband to @DrBiden, proud father and grandfather. Ready to build back better for all Americans. Official account is @POTUS.', 'url': 'https://t.co/UClrPuJpyZ', 'entities': {'url': {'urls': [{'url': 'https://t.co/UClrPuJpyZ', 'expanded_url': 'http://joebiden.com', 'display_url': 'joebiden.com', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 35261195, 'friends_count': 48, 'listed_count': 39764, 'created_at': 'Sun Mar 11 17:51:24 +0000 2007', 'favourites_count': 20, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': True, 'statuses_count': 8429, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '565959', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1308769664240160770/AfgzWVE7_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1308769664240160770/AfgzWVE7_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/939091/1626295479', 'profile_link_color': '233F94', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': 'EBEBFF', 'profile_text_color': '323232', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 12006, 'favorite_count': 70124, 'favorited': False, 'retweeted': False, 'lang': 'en'}, created_at=datetime.datetime(2022, 8, 25, 23, 50, 30, tzinfo=datetime.timezone.utc), id=1562950578296147968, id_str='1562950578296147968', full_text='In 2020, 81 million Americans voted to save our democracy.\n\nThat’s why Donald Trump isn’t just a former president. He’s a defeated former president.\n\nNow, you need to vote to save democracy again.', truncated=False, display_text_range=[0, 196], entities={'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []}, source='Twitter Web App', source_url='https://mobile.twitter.com', in_reply_to_status_id=None, in_reply_to_status_id_str=None, in_reply_to_user_id=None, in_reply_to_user_id_str=None, in_reply_to_screen_name=None, author=User(_api=<tweepy.api.API object at 0x0000018A39C1B2B0>, _json={'id': 939091, 'id_str': '939091', 'name': 'Joe Biden', 'screen_name': 'JoeBiden', 'location': 'Washington, DC', 'description': 'Husband to @DrBiden, proud father and grandfather. Ready to build back better for all Americans. Official account is @POTUS.', 'url': 'https://t.co/UClrPuJpyZ', 'entities': {'url': {'urls': [{'url': 'https://t.co/UClrPuJpyZ', 'expanded_url': 'http://joebiden.com', 'display_url': 'joebiden.com', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'p ...
#  Status(_api=<tweepy.api.API object at 0x0000018A39C1B2B0>, _json={'created_at': 'Thu Aug 25 23:41:19 +0000 2022', 'id': 1562948265040945154, 'id_str': '1562948265040945154', 'full_text': 'In Maryland to discuss what’s at stake in this election and how we will continue to deliver for the American people. Tune in now.\nhttps://t.co/hhDR6fnS10', 'truncated': False, 'display_text_range': [0, 153], 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/hhDR6fnS10', 'expanded_url': 'https://twitter.com/i/broadcasts/1djxXPWOEbexZ', 'display_url': 'twitter.com/i/broadcasts/1…', 'indices': [130, 153]}]}, 'source': '<a href="https://sproutsocial.com" rel="nofollow">Sprout Social</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 939091, 'id_str': '939091', 'name': 'Joe Biden', 'screen_name': 'JoeBiden', 'location': 'Washington, DC', 'description': 'Husband to @DrBiden, proud father and grandfather. Ready to build back better for all Americans. Official account is @POTUS.', 'url': 'https://t.co/UClrPuJpyZ', 'entities': {'url': {'urls': [{'url': 'https://t.co/UClrPuJpyZ', 'expanded_url': 'http://joebiden.com', 'display_url': 'joebiden.com', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 35261195, 'friends_count': 48, 'listed_count': 39764, 'created_at': 'Sun Mar 11 17:51:24 +0000 2007', 'favourites_count': 20, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': True, 'statuses_count': 8429, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '565959', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1308769664240160770/AfgzWVE7_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1308769664240160770/AfgzWVE7_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/939091/1626295479', 'profile_link_color': '233F94', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': 'EBEBFF', 'profile_text_color': '323232', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 623, 'favorite_count': 3030, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'lang': 'en'}, created_at=datetime.datetime(2022, 8, 25, 23, 41, 19, tzinfo=datetime.timezone.utc), id=1562948265040945154, id_str='1562948265040945154', full_text='In Maryland to discuss what’s at stake in this election and how we will continue to deliver for the American people. Tune in now.\nhttps://t.co/hhDR6fnS10', truncated=False, display_text_range=[0, 153], entities={'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/hhDR6fnS10', 'expanded_url': 'https://twitter.com/i/broadcasts/1djxXPWOEbexZ', 'display_url': 'twitter.com/i/broadcasts/1…', 'indices': [130, 153]}]}, source='Sprout Social', source_url='https://sproutsocial.com', in_reply_to_status_id=None, in_reply_to_status_id_str=None, in_reply_to_user_id=None, in_reply_to_user_id_str=None, in_reply_to_screen_name=None, author=User(_api=<tweepy.api.API object at 0x0000018A39C1B2B0>, _json={'id': 939091, 'id_str': '939091', 'name': 'Joe Biden', 'screen_name': 'JoeBiden', 'location': 'Washington, DC', 'description': 'Husband to @DrBiden, proud father and grandfather. Ready to build back better for all A ...
#  Status(_api=<tweepy.api.API object at 0x0000018A39C1B2B0>, _json={'created_at': 'Thu Aug 25 21:26:01 +0000 2022', 'id': 1562914214981029890, 'id_str': '1562914214981029890', 'full_text': 'Yesterday, we put out a plan to bring relief to millions of working and middle-class people with student loans.\n\nWe’re keeping my campaign promise and forgiving up to $10,000 of federal student loan debt for individuals making less than $125,000 a year.', 'truncated': False, 'display_text_range': [0, 253], 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []}, 'source': '<a href="https://sproutsocial.com" rel="nofollow">Sprout Social</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 939091, 'id_str': '939091', 'name': 'Joe Biden', 'screen_name': 'JoeBiden', 'location': 'Washington, DC', 'description': 'Husband to @DrBiden, proud father and grandfather. Ready to build back better for all Americans. Official account is @POTUS.', 'url': 'https://t.co/UClrPuJpyZ', 'entities': {'url': {'urls': [{'url': 'https://t.co/UClrPuJpyZ', 'expanded_url': 'http://joebiden.com', 'display_url': 'joebiden.com', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 35261195, 'friends_count': 48, 'listed_count': 39764, 'created_at': 'Sun Mar 11 17:51:24 +0000 2007', 'favourites_count': 20, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': True, 'statuses_count': 8429, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '565959', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1308769664240160770/AfgzWVE7_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1308769664240160770/AfgzWVE7_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/939091/1626295479', 'profile_link_color': '233F94', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': 'EBEBFF', 'profile_text_color': '323232', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 
org', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 2336406, 'friends_count': 73, 'listed_count': 12735, 'created_at': 'Sun Apr 13 20:23:13 +0000 2008', 'favourites_count': 1234, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': True, 'statuses_count': 38288, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '00AEF3', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': True, 'profile_image_url': 'http://pbs.twimg.com/profile_imag ...
#  Status(_api=<tweepy.api.API object at 0x0000018A39C1B2B0>, _json={'created_at': 'Mon Aug 22 17:16:01 +0000 2022', 'id': 1561764137667026945, 'id_str': '1561764137667026945', 'full_text': 'The Inflation Reduction Act will reduce the deficit without raising a penny in taxes on people making under $400,000 a year.', 'truncated': False, 'display_text_range': [0, 124], 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []}, 'source': '<a href="https://sproutsocial.com" rel="nofollow">Sprout Social</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 939091, 'id_str': '939091', 'name': 'Joe Biden', 'screen_name': 'JoeBiden', 'location': 'Washington, DC', 'description': 'Husband to @DrBiden, proud father and grandfather. Ready to build back better for all Americans. Official account is @POTUS.', 'url': 'https://t.co/UClrPuJpyZ', 'entities': {'url': {'urls': [{'url': 'https://t.co/UClrPuJpyZ', 'expanded_url': 'http://joebiden.com', 'display_url': 'joebiden.com', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 35261195, 'friends_count': 48, 'listed_count': 39764, 'created_at': 'Sun Mar 11 17:51:24 +0000 2007', 'favourites_count': 20, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': True, 'statuses_count': 8429, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '565959', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1308769664240160770/AfgzWVE7_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1308769664240160770/AfgzWVE7_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/939091/1626295479', 'profile_link_color': '233F94', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': 'EBEBFF', 'profile_text_color': '323232', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 3196, 'favorite_count': 18262, 'favorited': False, 'retweeted': False, 'lang': 'en'}, created_at=datetime.datetime(2022, 8, 22, 17, 16, 1, tzinfo=datetime.timezone.utc), id=1561764137667026945, id_str='1561764137667026945', full_text='The Inflation Reduction Act will reduce the deficit without raising a penny in taxes on people making under $400,000 a year.', truncated=False, display_text_range=[0, 124], entities={'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []}, source='Sprout Social', source_url='https://sproutsocial.com', in_reply_to_status_id=None, in_reply_to_status_id_str=None, in_reply_to_user_id=None, in_reply_to_user_id_str=None, in_reply_to_screen_name=None, author=User(_api=<tweepy.api.API object at 0x0000018A39C1B2B0>, _json={'id': 939091, 'id_str': '939091', 'name': 'Joe Biden', 'screen_name': 'JoeBiden', 'location': 'Washington, DC', 'description': 'Husband to @DrBiden, proud father and grandfather. Ready to build back better for all Americans. Official account is @POTUS.', 'url': 'https://t.co/UClrPuJpyZ', 'entities': {'url': {'urls': [{'url': 'https://t.co/UClrPuJpyZ', 'expanded_url': 'http://joebiden.com', 'display_url': 'joebiden.com', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 35261195, 'friends_count': 48, 'listed_count': 39764, 'created_at': 'Sun Mar 11 17:51:24 +0000 2007', 'favourites_count': 20, ...

# %%
def get_all_tweets(screen_name, start_date):
    '''
    Esta funcion recibe el nombre de la persona de quien queremos extraer los 
    tweets y devuelve una lista con todos los tweets y sus datos
    Input: 
      screen_name (str): el nombre de la persona en twitter
      start_date(datetime): fecha desde la que se quieren los tweets
    Output:
      all_tweets (lista): lista con todos los tweets extraidos
    '''
    # Solicitamos los 200 tweets mas recientes (200 es el maximo permitido en count)
    new_tweets = api.user_timeline(screen_name=screen_name, 
                                   tweet_mode="extended", count=200)
    # Creo una lista para almacenar TODOS los tweets y agrego los recién extraidos
    all_tweets = []
    all_tweets.extend(new_tweets)
    # guardo el id del ultimo tweet extraído 
    oldest = all_tweets[-1].id 
    
    # extraigo tweets de a 200 hasta que no haya más
    while len(new_tweets) > 0 and all_tweets[-1].created_at > start_date:
        # Solicito 200 tweets mas y los agrego a la lista de 'all_tweets'
        new_tweets = api.user_timeline(screen_name=screen_name, count=200,
                                       tweet_mode="extended", max_id=oldest-1)
        all_tweets.extend(new_tweets)
        # actualizo el id del ultimo tweet extraído
        oldest = all_tweets[-1].id 
        print("Hasta ahora se han extraido %s tweets" % len(all_tweets))

    return all_tweets

# %%
# Extraemos los tweets desde unos días antes de las elecciones del 
# 3 de Noviembre de 2020
date_before_elections = datetime(2020, 10, 16, 0, 0, 0, tzinfo=tz.utc)
all_tweets_biden = get_all_tweets("JoeBiden", date_before_elections)
# Out:
# Hasta ahora se han extraido 400 tweets
# Hasta ahora se han extraido 600 tweets
# Hasta ahora se han extraido 800 tweets
# Hasta ahora se han extraido 1000 tweets
# Hasta ahora se han extraido 1200 tweets
# Hasta ahora se han extraido 1400 tweets
# Hasta ahora se han extraido 1600 tweets
# Hasta ahora se han extraido 1799 tweets
# Hasta ahora se han extraido 1999 tweets
# Hasta ahora se han extraido 2199 tweets

# %%
#Veamos la lista con los primeros 5 objetos de tweepy 
all_tweets_biden[:5]
# Out:
# [Status(_api=<tweepy.api.API object at 0x0000018A39C1B2B0>, _json={'created_at': 'Fri Aug 26 23:07:00 +0000 2022', 'id': 1563302019032846336, 'id_str': '1563302019032846336', 'full_text': 'Senator Rick Scott wrote the only election-year plan the GOP has this year—in it, he wants to require Congress to vote on the future of Social Security every 5 years.\n\nDo you want to put your Social Security into the hands of Ted Cruz or Marjorie Taylor Greene?', 'truncated': False, 'display_text_range': [0, 261], 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []}, 'source': '<a href="https://sproutsocial.com" rel="nofollow">Sprout Social</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 939091, 'id_str': '939091', 'name': 'Joe Biden', 'screen_name': 'JoeBiden', 'location': 'Washington, DC', 'description': 'Husband to @DrBiden, proud father and grandfather. Ready to build back better for all Americans. Official account is @POTUS.', 'url': 'https://t.co/UClrPuJpyZ', 'entities': {'url': {'urls': [{'url': 'https://t.co/UClrPuJpyZ', 'expanded_url': 'http://joebiden.com', 'display_url': 'joebiden.com', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 35260486, 'friends_count': 48, 'listed_count': 39759, 'created_at': 'Sun Mar 11 17:51:24 +0000 2007', 'favourites_count': 20, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': True, 'statuses_count': 8429, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '565959', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1308769664240160770/AfgzWVE7_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1308769664240160770/AfgzWVE7_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/939091/1626295479', 'profile_link_color': '233F94', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': 'EBEBFF', 'profile_text_color': '323232', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 8534, 'favorite_count': 31054, 'favorited': False, 'retweeted': False, 'lang': 'en'}, created_at=datetime.datetime(2022, 8, 26,
description': 'Husband to @DrBiden, proud father and grandfather. Ready to build back better for all Americans. Official account is @POTUS.', 'url': 'https://t.co/UClrPuJpyZ', 'entities': {'url': {'urls': [{'url': 'https://t.co/UClrPuJpyZ', 'expanded_url': 'http://joebiden.com', 'display_url': 'joebiden.com', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'f ...

# %%
# Veamos un solo tweet 
all_tweets_biden[8].full_text
# Out:
# 'In 2020, 81 million Americans voted to save our democracy.\n\nThat’s why Donald Trump isn’t just a former president. He’s a defeated former president.\n\nNow, you need to vote to save democracy again.'

# %%
def save_tweets_text(all_tweets, csv_file=None):
    '''
    Esta función guarda los tweets en un data frame y si se especifica un 
    archivo csv tambien se guardaran ahí 
    Input:
        all_tweets (lista): lista con tweets y sus datos
        csv_file ('str'): nombre del archivo csv
    Output:
        df_all_tweets (df): tweets ordenados en una tabla con datos seleccinados
    '''
    all_tweets_selection = []
    for tweet in all_tweets:
        one_tweet = [tweet.id_str, tweet.created_at, tweet.full_text, 
                     tweet.retweeted, tweet.favorite_count, 
                     tweet.in_reply_to_screen_name]
        all_tweets_selection.append(one_tweet)
    
    df_all_tweets = pd.DataFrame(all_tweets_selection)
    df_all_tweets.columns = ['id_str', 'created_at', 'text', 'retweeted',
                            'favorite_count', 'in_reply_to_screen_name']
    if csv_file:
        df_all_tweets.to_csv(csv_file, index=False, encoding="utf-8")

    return df_all_tweets

# %%
help(save_tweets_text)
# Out:
# Help on function save_tweets_text in module __main__:
#
# save_tweets_text(all_tweets, csv_file=None)
#     Esta función guarda los tweets en un data frame y si se especifica un
#     archivo csv tambien se guardaran ahí
#     Input:
#         all_tweets (lista): lista con tweets y sus datos
#         csv_file ('str'): nombre del archivo csv
#     Output:
#         df_all_tweets (df): tweets ordenados en una tabla con datos seleccinados

# %%
df_all_tweets = save_tweets_text(all_tweets_biden, "tweets.csv")
df_all_tweets
# Out:
#                    id_str                created_at  \
# 0     1563302019032846336 2022-08-26 23:07:00+00:00
# 1     1563283902898114562 2022-08-26 21:55:01+00:00
# 2     1563237850115878917 2022-08-26 18:52:01+00:00
# 3     1563213196348993542 2022-08-26 17:14:03+00:00
# 4     1562955005228765186 2022-08-26 00:08:06+00:00
# ...                   ...                       ...
# 2194  1316840627817066496 2020-10-15 20:37:26+00:00
# 2195  1316840452235186178 2020-10-15 20:36:44+00:00
# 2196  1316831214821548033 2020-10-15 20:00:01+00:00
# 2197  1316819884081393667 2020-10-15 19:15:00+00:00
# 2198  1316808561435967488 2020-10-15 18:30:00+00:00
#
#                                                    text  retweeted  \
# 0     Senator Rick Scott wrote the only election-yea...      False
# 1     Under my student debt relief plan, almost 90% ...      False
# 2     10 million jobs—more than ever created before ...      False
# 3     Every Republican in Congress voted against low...      False
# 4     Wall Street didn’t build this country. You did...      False
# ...                                                 ...        ...
# 2194  Not only was the individual 50+ feet away and ...      False
# 2195  During our contact tracing, we discovered arou...      False
# 2196  Donald Trump is rushing through Justice Ginsbu...      False
# 2197  President Obama and I left Donald Trump a boom...      False
# 2198  Nevada — today is the last day to register to ...      False
#
#       favorite_count in_reply_to_screen_name
# 0              31054                    None
# 1              17522                    None
# 2               9865                    None
# 3              12850                    None
# 4              23208                    None
# ...              ...                     ...
# 2194           33911                JoeBiden
# 2195           79439                    None
# 2196           11877                    None
# 2197          310102                    None
# 2198            8217                    None
#
# [2199 rows x 6 columns]

# %%
# Emoticons contentos
emoticons_happy = set([
    ':-)', ':)', ';)', ':o)', ':]', ':3', ':c)', ':>', '=]', '8)', '=)', ':}',
    ':^)', ':-D', ':D', '8-D', '8D', 'x-D', 'xD', 'X-D', 'XD', '=-D', '=D',
    '=-3', '=3', ':-))', ":'-)", ":')", ':*', ':^*', '>:P', ':-P', ':P', 'X-P',
    'x-p', 'xp', 'XP', ':-p', ':p', '=p', ':-b', ':b', '>:)', '>;)', '>:-)',
    '<3'
    ])
 
# Emoticons Tristes
emoticons_sad = set([
    ':L', ':-/', '>:/', ':S', '>:[', ':@', ':-(', ':[', ':-||', '=L', ':<',
    ':-[', ':-<', '=\\', '=/', '>:(', ':(', '>.<', ":'-(", ":'(", ':\\', ':-c',
    ':c', ':{', '>:\\', ';('
    ])

#combine sad and happy emoticons
emoticons = emoticons_happy.union(emoticons_sad)

# %%
#Emoji patterns
emoji_pattern = re.compile("["
                           u"\U0001F600-\U0001F64F"  # emoticons
                           u"\U0001F300-\U0001F5FF"  # simbolos & pictogramas
                           u"\U0001F680-\U0001F6FF"  # transporte & simbolos mapas
                           u"\U0001F1E0-\U0001F1FF"  # banderas (iOS)
                           u"\U00002702-\U000027B0"
                           u"\U000024C2-\U0001F251"
                           "]+", flags=re.UNICODE)

# %%
#mrhod clean_tweets()
def clean_tweets(tweet):
    '''
    Esta función limpia el texto del tweet. Elimina emoticones, palabras vacías,
    links, indicaciones de retweets, etc. Para dejar en el texto solo las
    palabras con mayor contenido.
    Input:
        tweet (str): Texto del tweet original
    Output:
        tweet (str): Texto del tweet limpiado
    '''
    #Elimino caracteres de re-tweets   
    tweet = re.sub(r'^RT .*:', '', tweet)
    tweet = re.sub(r'@\S+', '', tweet)
    tweet = re.sub(r':', '', tweet)
    tweet = re.sub(r'‚Ä¶', '', tweet)
    #Reemplazo caracteres non-ASCII con espacio
    tweet = re.sub(r'[^\x00-\x7F]+',' ', tweet)
    #Saco los links
    tweet = re.sub(r'https.*', '', tweet)
    #Saco los emoji
    tweet = emoji_pattern.sub(r'', tweet)
    
    #Separo los tweets in tokens
    word_tokens = word_tokenize(tweet)
    #Obtengo set de palabras vacias para luego eliminarlas
    stop_words = set(stopwords.words('english'))
    
    #loop por las condiciones
    filtered_tweet = []
    for w in word_tokens:
        #check tokens against stop words , emoticons and punctuations
        if w not in stop_words and w not in emoticons and \
           w not in string.punctuation:
            filtered_tweet.append(w)

    
    return ' '.join(filtered_tweet)

# %%
#Este es un tweet sucio:
df_all_tweets.iloc[0]['text']
# Out:
# 'Senator Rick Scott wrote the only election-year plan the GOP has this year—in it, he wants to require Congress to vote on the future of Social Security every 5 years.\n\nDo you want to put your Social Security into the hands of Ted Cruz or Marjorie Taylor Greene?'

# %%
#Este es un tweet limpio:
clean_tweets(df_all_tweets.iloc[0]['text'])
# Out:
# 'Senator Rick Scott wrote election-year plan GOP year wants require Congress vote future Social Security every 5 years Do want put Social Security hands Ted Cruz Marjorie Taylor Greene'

# %%
def filter_year_and_month(date_tweet, start_time, end_time):
    '''
    Recibe una fecha y devuelve True, si la fecha de la fila esta 
    dentro de los dias especificados como inicio y fin, caso 
    contrario False.
    '''
    dd = pd.to_datetime(date_tweet).date()
    return dd > start_time and dd < end_time

# %%
def generate_sentiment(texto):
    '''
    Esta funcion limpia el texto y analiza el sentimiento.
    Input:
        texto (str): texto a limpiar y analizar
    Output:
         polarity (float): en el rango [-1.0, 1.0] 
         subjectivity (float): en el rango [0.0, 1.0] 
    '''
    # Limpiamos el texto del tweet
    filtered_tweet = clean_tweets(texto)
    # Calculamos el sentimiento con el metodo TextBlob
    blob = TextBlob(filtered_tweet)
    Sentiment = blob.sentiment

    polarity = Sentiment.polarity
    subjectivity = Sentiment.subjectivity            

    return polarity, subjectivity

# %% [markdown]
# Polarity: Negative (-1.0) vs. Positive (1.0)
#
# Subjectivity: Objective (0.0) vs. Subjective (1.0)

# %%
def add_sentiment(df, start_time, end_time):
    '''
    Esta funcion filtra los tweets entre las fechas de inicio y fin
    indicadas y agrega dos columnas, una de polarity y otra de subjectivity.
    Input:
        df (dataframe): tabla con los tweets en una columa llamada text
        start_time (datetime): fecha del tweet más antiguo a conservar
        end_time (datetime): fecha del tweet más reciente a conservar
    Output:
        df (dataframe): df actualizado con el filtro y nuevas columnas
    '''
    df = df[df.apply(lambda row: filter_year_and_month(row['created_at'], 
                                                start_time, end_time), axis=1)]

    df[["polarity", "subjectivity"]] = pd.DataFrame(df.apply(lambda row: \
                                            generate_sentiment(row['text']), \
                                            axis=1).tolist(), index=df.index)
    
    return df

# %%
start_time = datetime.strptime("2020-10-20", '%Y-%m-%d').date()
end_time = datetime.strptime("2020-11-18", '%Y-%m-%d').date()

# %%
tweets_sentimiento = add_sentiment(df_all_tweets, start_time, end_time)
tweets_sentimiento
# Out:
# C:\Users\Matias\AppData\Local\Temp\ipykernel_14288\548788201.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[["polarity", "subjectivity"]] = pd.DataFrame(df.apply(lambda row: \
# C:\Users\Matias\AppData\Local\Temp\ipykernel_14288\548788201.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[["polarity", "subjectivity"]] = pd.DataFrame(df.apply(lambda row: \
#                    id_str                created_at  \
# 1611  1328837822950752259 2020-11-17 23:10:00+00:00
# 1612  1328790008963227649 2020-11-17 20:00:00+00:00
# 1613  1328734005404061701 2020-11-17 16:17:28+00:00
# 1614  1328474177007972354 2020-11-16 23:05:00+00:00
# 1615  1328467885279375361 2020-11-16 22:40:00+00:00
# ...                   ...                       ...
# 2100  1318937589097717760 2020-10-21 15:30:00+00:00
# 2101  1318919971653578752 2020-10-21 14:20:00+00:00
# 2102  1318915442153562115 2020-10-21 14:02:00+00:00
# 2103  1318753877076881408 2020-10-21 03:20:00+00:00
# 2104  1318714870024540160 2020-10-21 00:45:00+00:00
#
#                                                    text  retweeted  \
# 1611  Today, @KamalaHarris and I met with some of ou...      False
# 1612  I’m keeping in my prayers all of our friends a...      False
# 1613  RT @Transition46: Our White House senior staff...      False
# 1614  Americans want us to cooperate. They want us t...      False
# 1615  When we build back better, we will do so with ...      False
# ...                                                 ...        ...
# 2100  Justice is on the ballot.\n\nhttps://t.co/eoxT...      False
# 2101  West Virginia — in-person early voting is now ...      False
# 2102  Missouri — today is the last day to request a ...      False
# 2103  It’s time we see each other as fellow American...      False
# 2104  I’ve always believed we’re at our best when we...      False
#
#       favorite_count in_reply_to_screen_name  polarity  subjectivity
# 1611          112578                    None  0.500000      0.700000
# 1612          258166                    None  0.266667      0.583333
# 1613               0                    None  0.000000      0.000000
# 1614          128990                    None  0.500000      0.812500
# 1615          189223                    None  0.250000      0.285714
# ...              ...                     ...       ...           ...
# 2100           22990                    None  0.000000      0.000000
# 2101           17452                    None  0.050000      0.400000
# 2102           13937                    None  0.000000      0.066667
# 2103          108723                    None  0.318182      0.550000
# 2104          120889                    None  0.464286      0.257143
#
# [494 rows x 8 columns]

# %%
tweets_sentimiento.shape
# Out:
# (494, 8)

# %% [markdown]
# ## Trabajo Practico 1 - Parte 2

# %% [markdown]
# ### Reglas de formato y presentación
# - El trabajo debe estar bien comentado (utilizando #) para que el codigo sea facíl de entender por sus compañeros y profesores.
#
# - El mismo debe ser completado en este Jupyter Notebook y entregado como tal, es decir en un archivo .ipynb

# %% [markdown]
# ### Fecha de entrega:
# Lunes 29/8 a las 23:59hs

# %% [markdown]
# ### Modalidad de entrega
# - Al finalizar el trabajo práctico deben hacer un último <i>commit</i> en su repositorio de GitHub con el mensaje “Entrega final del tp”.
# - Asegurense de haber creado una carpeta llamada TP1. Este Jupyter Notebook y el correspondiente al TP1 - Parte 1 deben estar dentro de esa carpeta.
# - Tambíen deben completar el link de su repositorio -para que pueda ser clonado y corregido- en la siguiente google sheet: https://docs.google.com/spreadsheets/d/1qaXCveEw3MjEwXQsu2zpqUz34BiaCMR0WapcsQ7jGs0/edit?usp=sharing
# - La última versión en el repositorio es la que será evaluada. Por lo que es importante que:
#     - No completen la google sheet hasta no haber terminado y estar seguros de que han hecho el <i>commit y push</i> a la versión final que quieren entregar. Debido a que se pueden tomar hasta 3 días de extensión a lo largo del curso, yo no corregiré sus tareas hasta no ver el link en la google sheet.
#     - No hagan nuevos <i>push</i> despues de habér entregado su versión final. Esto generaría confusión acerca de que versión es la que quieren que se les corrija.

# %% [markdown]
# #### Ejercicio 1:
# Impriman algunos de los tweets más negativos (filtrando por la columna de `polarity`) y su fecha

# %%
#Utilizamos el código visto en la tutorial e instalamos los paquetes que nos faltaban. Tomamos eso como base para el web scraping.

df_tw_neg = tweets_sentimiento.query("`polarity` <0") #Generamos un nuevo data frame filtrando las observaciones con polaridad negativa.
df_tw_neg.filter(["text", "polarity", "created_at"]) #Visualizamos el nuevo data frame con las columnas que nos interesan.
# Out:
#                                                    text  polarity  \
# 1626  Today marks five years since the horrific ISIS... -0.650000
# 1634  If you’re sick, if you’re struggling, if you’r... -0.714286
# 1635  When I’m speaking to foreign leaders, I’m tell... -0.131250
# 1648  I spent the morning with the co-chairs of my C... -0.100000
# 1660  It’s time to put away the harsh rhetoric.\n\nT... -0.200000
# 1679  I spent the afternoon attending briefings on t... -0.100000
# 1681  Democracy is sometimes messy, so sometimes it ... -0.193750
# 1694  Once this election is finalized and behind us,... -0.333333
# 1727  RT @KamalaHarris: The 2016 election was lost b... -0.125000
# 1764  After tonight's horrific terrorist attack in V... -0.900000
# 1767  Donald Trump is the most corrupt president in ... -0.180000
# 1779  In public, President Trump compared COVID-19 t... -0.016667
# 1800  Our president has failed in his most basic dut... -0.250000
# 1814  From Arizona to Georgia to Wisconsin and beyon... -0.145833
# 1821  Scranton, Pennsylvania, isn't just where I'm f... -0.035714
# 1830  It’s long past time we take action to end the ... -0.050000
# 1835  The Trump Administration knew how deadly this ... -0.100000
# 1841  If you’re sick or struggling or worried about ... -0.357143
# 1846  My faith has been a source of immeasurable sol... -0.266667
# 1847  Right now:\n \n- Almost 23 million Americans a... -0.016071
# 1851  We have in our hands the ultimate power: the p... -0.100000
# 1861  The hard truth is that under President Trump, ... -0.545833
# 1887  RT @TeamJoe: 🚨3 days until Election Day🚨 \n\nI... -0.300000
# 1889  President Trump still has no plan to address C... -0.300000
# 1898  This Domestic Violence Awareness Month, I reco... -0.020000
# 1918  This election is about so much more than polic... -0.030556
# 1925  Donald Trump is on track to become the worst j... -0.266667
# 1927  Jill and I are keeping the French people in ou... -0.100000
# 1935  GDP rose last quarter, but visits to food bank... -0.019444
# 1948  It’s hard to believe it’s been a year since we... -0.077652
# 1950  As president, I'll build on Obamacare to ensur... -0.035714
# 1964  Our hearts are broken for the family of Walter... -0.188889
# 1970  Black lives matter. No president should be afr... -0.383333
# 1972  This is our opportunity to leave the dark, ang... -0.325000
# 1986  It didn’t have to be this bad — and as @Michel... -0.266667
# 1988  RT @DrBiden: I remember what it was like when ... -0.100000
# 1997  Jacquelyn — I was honored to meet you in Decem... -0.050000
# 1998  Thank you @iamwill and @IAMJHUD for this power... -0.166667
# 1999  There is a real human toll to President Trump'... -0.250000
# 2005  The hard truth is it didn't have to be this ba... -0.347222
# 2020  President Trump called India "filthy."\n\nIt's... -0.170833
# 2037  A slight change of tone from the president for... -0.333333
# 2054  Kids were ripped from their parents’ arms, and... -0.400000
# 2061  He’s a confused guy. He doesn’t know who he’s ... -0.400000
# 1616  Right now, Congress should come together and p...  0.246429
# ...                                                 ...       ...
# 2098  Every day it seems we uncover new horrors perp...  0.136364
# 2099  The Build Back Better Express Tour was about m...  0.300000
# 2101  West Virginia — in-person early voting is now ...  0.050000
# 2103  It’s time we see each other as fellow American...  0.318182
# 2104  I’ve always believed we’re at our best when we...  0.464286
#
#                     created_at
# 1611 2020-11-17 23:10:00+00:00
# 1612 2020-11-17 20:00:00+00:00
# 1614 2020-11-16 23:05:00+00:00
# 1615 2020-11-16 22:40:00+00:00
# 1616 2020-11-16 22:15:00+00:00
# ...                        ...
# 2098 2020-10-21 18:36:13+00:00
# 2099 2020-10-21 17:02:00+00:00
# 2101 2020-10-21 14:20:00+00:00
# 2103 2020-10-21 03:20:00+00:00
# 2104 2020-10-21 00:45:00+00:00
#
# [231 rows x 3 columns]

# %% [markdown]
# ###### Ejercicio 3:
# Agreguenle al df llamado `tweets_sentimiento` una nueva columna llamada `positivo` que tenga:
# - 1 cuando el tweet tiene polarity > 0,
# - 0 cuando el tweet tiene polarity = 0,
# - -1 cuando el tweet tiene polarity < 0

# %%
positivity = 0 #Generamos una variable para la positividad y le damos valor de base cero.

#Creamos una función que analice la positividad de la polaridad

def generate_positividad(polarity):
    '''
    Esta funcion analiza la polaridad.
    Input:
        polarity (float): valor a analizar
    Output:
         positivity(int): toma los valores 1 cuando la polaridad es > 0, 0 cuando la polaridad es = 0 y -1 cuando la polaridad es < 0. 
    '''
    # Analizamos la polaridad
    if polarity > 0:
        positivity = 1
    elif polarity == 0:
        positivity = 0
    else:
        positivity = -1

    return positivity

# %%
#Generamos una función que agregue la columna solicitada en la consigna.

def add_positividad(df):
    '''
    Esta funcion agrega la columna de positivity al data frame.
    Input:
        df (dataframe): tabla con los tweets, que contiene una columna llamada polarity
        positity
    Output:
        df (dataframe): df actualizado con la nueva columan de positividad
    '''

    df[["positivo"]] = pd.DataFrame(df.apply(lambda row: \
                                            generate_positividad(row['polarity']), \
                                            axis=1).tolist(), index=df.index)
    
    return df

tweets_sentimiento = add_positividad(tweets_sentimiento) #Corremos la función con nuestro data frame de interés.
tweets_sentimiento #Visualizamos el nuevo data frame.

#Como en la visualización no veíamos positividad negativa, probamos filtrar alguno para corroborar que funcione bien.
#tweets_sentimiento.query("`positivo` ==-1")
# Out:
# C:\Users\Matias\AppData\Local\Temp\ipykernel_14288\1909837665.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[["positivo"]] = pd.DataFrame(df.apply(lambda row: \
#                    id_str                created_at  \
# 1611  1328837822950752259 2020-11-17 23:10:00+00:00
# 1612  1328790008963227649 2020-11-17 20:00:00+00:00
# 1613  1328734005404061701 2020-11-17 16:17:28+00:00
# 1614  1328474177007972354 2020-11-16 23:05:00+00:00
# 1615  1328467885279375361 2020-11-16 22:40:00+00:00
# ...                   ...                       ...
# 2100  1318937589097717760 2020-10-21 15:30:00+00:00
# 2101  1318919971653578752 2020-10-21 14:20:00+00:00
# 2102  1318915442153562115 2020-10-21 14:02:00+00:00
# 2103  1318753877076881408 2020-10-21 03:20:00+00:00
# 2104  1318714870024540160 2020-10-21 00:45:00+00:00
#
#                                                    text  retweeted  \
# 1611  Today, @KamalaHarris and I met with some of ou...      False
# 1612  I’m keeping in my prayers all of our friends a...      False
# 1613  RT @Transition46: Our White House senior staff...      False
# 1614  Americans want us to cooperate. They want us t...      False
# 1615  When we build back better, we will do so with ...      False
# ...                                                 ...        ...
# 2100  Justice is on the ballot.\n\nhttps://t.co/eoxT...      False
# 2101  West Virginia — in-person early voting is now ...      False
# 2102  Missouri — today is the last day to request a ...      False
# 2103  It’s time we see each other as fellow American...      False
# 2104  I’ve always believed we’re at our best when we...      False
#
#       favorite_count in_reply_to_screen_name  polarity  subjectivity  positivo
# 1611          112578                    None  0.500000      0.700000         1
# 1612          258166                    None  0.266667      0.583333         1
# 1613               0                    None  0.000000      0.000000         0
# 1614          128990                    None  0.500000      0.812500         1
# 1615          189223                    None  0.250000      0.285714         1
# ...              ...                     ...       ...           ...       ...
# 2100           22990                    None  0.000000      0.000000         0
# 2101           17452                    None  0.050000      0.400000         1
# 2102           13937                    None  0.000000      0.066667         0
# 2103          108723                    None  0.318182      0.550000         1
# 2104          120889                    None  0.464286      0.257143         1
#
# [494 rows x 9 columns]

# %% [markdown]
# #### Ejercicio 4:
# Agrupen los tweets por día y promedien el la polaridad. Luego hagan un gráfico con el sentimiento por día.

# %%
import matplotlib.pyplot as plt

# %%
# Creamos una nueva variable en nuestro data frame con un formato de fecha (aa-mm-dd), eliminando la hora del tweet
tweets_sentimiento["fecha"] = tweets_sentimiento["created_at"].dt.strftime("%y-%m-%d")
# Visualizamos el nuevo data frame
tweets_sentimiento
# Out:
# C:\Users\Matias\AppData\Local\Temp\ipykernel_14288\4251442625.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tweets_sentimiento["fecha"] = tweets_sentimiento["created_at"].dt.strftime("%y-%m-%d")
#                    id_str                created_at  \
# 1611  1328837822950752259 2020-11-17 23:10:00+00:00
# 1612  1328790008963227649 2020-11-17 20:00:00+00:00
# 1613  1328734005404061701 2020-11-17 16:17:28+00:00
# 1614  1328474177007972354 2020-11-16 23:05:00+00:00
# 1615  1328467885279375361 2020-11-16 22:40:00+00:00
# ...                   ...                       ...
# 2100  1318937589097717760 2020-10-21 15:30:00+00:00
# 2101  1318919971653578752 2020-10-21 14:20:00+00:00
# 2102  1318915442153562115 2020-10-21 14:02:00+00:00
# 2103  1318753877076881408 2020-10-21 03:20:00+00:00
# 2104  1318714870024540160 2020-10-21 00:45:00+00:00
#
#                                                    text  retweeted  \
# 1611  Today, @KamalaHarris and I met with some of ou...      False
# 1612  I’m keeping in my prayers all of our friends a...      False
# 1613  RT @Transition46: Our White House senior staff...      False
# 1614  Americans want us to cooperate. They want us t...      False
# 1615  When we build back better, we will do so with ...      False
# ...                                                 ...        ...
# 2100  Justice is on the ballot.\n\nhttps://t.co/eoxT...      False
# 2101  West Virginia — in-person early voting is now ...      False
# 2102  Missouri — today is the last day to request a ...      False
# 2103  It’s time we see each other as fellow American...      False
# 2104  I’ve always believed we’re at our best when we...      False
#
#       favorite_count in_reply_to_screen_name  polarity  subjectivity  \
# 1611          112578                    None  0.500000      0.700000
# 1612          258166                    None  0.266667      0.583333
# 1613               0                    None  0.000000      0.000000
# 1614          128990                    None  0.500000      0.812500
# 1615          189223                    None  0.250000      0.285714
# ...              ...                     ...       ...           ...
# 2100           22990                    None  0.000000      0.000000
# 2101           17452                    None  0.050000      0.400000
# 2102           13937                    None  0.000000      0.066667
# 2103          108723                    None  0.318182      0.550000
# 2104          120889                    None  0.464286      0.257143
#
#       positivo     fecha
# 1611         1  20-11-17
# 1612         1  20-11-17
# 1613         0  20-11-17
# 1614         1  20-11-16
# 1615         1  20-11-16
# ...        ...       ...
# 2100         0  20-10-21
# 2101         1  20-10-21
# 2102         0  20-10-21
# 2103         1  20-10-21
# 2104         1  20-10-21
#
# [494 rows x 10 columns]

# %%
# Agrupamos los tweets por fecha y promediamos su polaridad
tweets_dia_agg = tweets_sentimiento.groupby(by = ["fecha"]).agg({"polarity":"mean"})
# Reseteamos el índice para que fecha no sea tomado como tal
tweets_dia_agg . reset_index ( inplace = True )
# Visualizamos el nuevo data frame
tweets_dia_agg
# Out:
#        fecha  polarity
# 0   20-10-21  0.122063
# 1   20-10-22  0.132929
# 2   20-10-23  0.122758
# 3   20-10-24  0.035287
# 4   20-10-25  0.081356
# 5   20-10-26  0.118350
# 6   20-10-27  0.058696
# 7   20-10-28  0.077308
# 8   20-10-29  0.120751
# 9   20-10-30  0.077652
# 10  20-10-31  0.105104
# 11  20-11-01  0.088387
# 12  20-11-02  0.152486
# 13  20-11-03  0.083676
# 14  20-11-04  0.159632
# 15  20-11-05  0.113942
# 16  20-11-06  0.172222
# 17  20-11-07  0.152171
# 18  20-11-08  0.207940
# 19  20-11-09  0.034970
# 20  20-11-10  0.047917
# 21  20-11-11  0.138095
# 22  20-11-12  0.170000
# 23  20-11-13 -0.325000
# 24  20-11-14  0.218506
# 25  20-11-15  0.366667
# 26  20-11-16  0.321276
# 27  20-11-17  0.255556

# %%
# Definimos los vectores de datos para el gráfico
y1 = tweets_dia_agg["polarity"]
x1 = tweets_dia_agg["fecha"]

# %%
# Creamos el gráfico

plt.plot(x1, y1)

#Modificamos las labels
plt.xlabel("Fecha")
plt.ylabel("Polaridad")
plt.title("Promedio diario de polaridad de los tweets")
plt.xticks(rotation =45, size=7)

plt.show() #esto es  necesario  para  visualizar

# %% [markdown]
# #### Repaso del análisis de sentimiento:
# Por último, los invito a que exploren el análisis de sentimiento de forma teórica y práctica:
# - Revisen la documentación de `TextBlob` y del método `sentiment` https://textblob.readthedocs.io/en/dev/
# - Prueben en la practica el resultado que arroja para determinadas frases (les dejo unos ejemplos, pero pueden probar los que quieran)

# %%
testimonial = TextBlob("Big Data is so much fun!")
testimonial.sentiment
# Out:
# Sentiment(polarity=0.1875, subjectivity=0.15000000000000002)

# %%
testimonial2 = TextBlob("Big Data is horrible!")
testimonial2.sentiment
# Out:
# Sentiment(polarity=-0.5, subjectivity=0.55)

# %% [markdown]
# #### Análisis de lo que probamos:
# Tomando como ejemplo los comandos que se presentan en la página, probamos con dos frases que tuvieran sentimientos opuestos. Podemos ver que en el primer caso la polaridad efectivamente es positiva, mientras que en el segundo es más negativa. Con respecto a la subjetividad, vemos que también varía.
